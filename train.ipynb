# %%
# !gdown --id 17EjaIIj3YGiemA9cJD2so2i9ZdMIJ5Vb
# Out:
# /usr/local/lib/python3.7/dist-packages/gdown/cli.py:131: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   category=FutureWarning,
# Downloading...
# From: https://drive.google.com/uc?id=17EjaIIj3YGiemA9cJD2so2i9ZdMIJ5Vb
# To: /content/data.zip
# 100% 417M/417M [00:05<00:00, 73.2MB/s]

# %%
# !unzip data.zip

# %%
yaml = """
train: /content/content/train_data/images
val: /content/content/train_data/images/val

nc: 2
names: ['yes', 'no']"""

with open("data.yaml", 'w') as file:
    file.write(yaml)

# %%
# !git clone https://github.com/ultralytics/yolov5

# %%
# %cd /content/yolov5
# Out:
# /content/yolov5

# %%
# %pwd
# Out:
# '/content/yolov5'

# %%
# !pip install -r requirements.txt

# %%
# !python train.py --weights yolov5n.pt --data /content/data.yaml  --epoch 100 --batch-size 32
# Out:
# train: weights=yolov5n.pt, cfg=, data=/content/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=100, batch_size=32, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.1-380-gb551098 Python-3.7.13 torch-1.12.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %%
# !python detect.py --source /content/image_2022-08-09_185734947.png --weights /content/yolov5/runs/train/exp2/weights/best.pt
# Out:
# detect: weights=['/content/yolov5/runs/train/exp2/weights/best.pt'], source=/content/image_2022-08-09_185734947.png, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-379-gf5335f2 Python-3.7.13 torch-1.12.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/image_2022-08-09_185734947.png: 448x640 11 yess, 1 no, Done. (0.012s)
# Speed: 0.5ms pre-process, 12.1ms inference, 1.4ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp2

# %%
# !du -sh  /content/yolov5/runs/train/exp2/weights/best.pt
# Out:
# 3.8M	/content/yolov5/runs/train/exp2/weights/best.pt

# %% [markdown]
# # copy to drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp /content/yolov5/runs/train/exp2/weights/best.pt /content/drive/MyDrive/
